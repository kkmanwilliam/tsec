# %% [markdown]
# ### To Do List
# ##### Done
# * check all data form (sii, otc, pub, rotc)
#
# ##### Not Yet
# * design storage structure
# * build up sqlite3 db table / csv version as well
# * parsing with loop (and using tenacity)
# * make it a independ .py file
# * set cron job and keep the code clean

# %%
import requests
import pandas as pd
import numpy as np
import math
import os
from tenacity import retry, stop_after_attempt, wait_fixed
from datetime import datetime, timedelta

# %%
@retry(stop=stop_after_attempt(3), wait=wait_fixed(5))
def financial_statement(year, season, type='PL'):

    if year >= 1000:
        year -= 1911

    if type == 'PL': # 綜合損益彙總表
        url = 'https://mops.twse.com.tw/mops/web/ajax_t163sb04'
    elif type == 'BS': # 資產負債彙總表
        url = 'https://mops.twse.com.tw/mops/web/ajax_t163sb05'
    else:
        print('type does not match')
    
    df_final = pd.DataFrame()
    
    for corp_type in ["sii", "otc", "pub", "rotc"]:
        r = requests.post(url, {
            'encodeURIComponent':1,
            'step':1,
            'firstin':1,
            'off':1,
            'TYPEK':corp_type,# sii上市，otc上櫃，rotc興櫃，pub公開發行
            'year':str(year),
            'season':str(season),
        })

        r.encoding = 'utf8'
            
        dfs = pd.read_html(r.text, header=None)
        df = pd.concat(dfs[1:], axis=0, sort=False)
        df['年份'] = pd.Series([year] * df.shape[0])
        df['季度'] = pd.Series([season] * df.shape[0])
        df = pd.set_index(['公司名稱']).apply(lambda s: pd.to_numeric(s, errors='ceorce'))
        df['年份'] = pd.Series([year] * df.shape[0])
        df['季度'] = pd.Series([season] * df.shape[0])
        df['公司名稱'] = df.index
        df['公司代號'] = df['公司代號'].astype(str)
        df = df.set_index('公司代號')
        df_final = pd.concat([df_final, df], axis=0, sort=False)
            
    return df_final

@retry(stop=stop_after_attempt(3), wait=wait_fixed(5))
def financial_analysis(year, season): # 營益分析彙總表
    
    if year >= 1000:
        year -= 1911
    
    url = 'https://mops.twse.com.tw/mops/web/ajax_t163sb06'
    
    df_final = pd.DataFrame()
    
    for corp_type in ["sii", "otc", "pub", "rotc"]:
        try:
            r = requests.post(url, {
                'encodeURIComponent':1,
                'step':1,
                'firstin':1,
                'off':1,
                'TYPEK':corp_type, #otc pub rotc sii
                'year':str(year),
                'season':str(season),
            })
        
            r.encoding = 'utf8'
            dfs = pd.read_html(r.text, header=None)
            dfs[0].columns = dfs[0].iloc[0]
            df = dfs[0]
            df['年份'] = pd.Series([year] * df.shape[0])
            df['季度'] = pd.Series([season] * df.shape[0])
            df = df.set_index(['公司名稱']).apply(lambda s: pd.to_numeric(s, errors='ceorce'))
            df = df[~df['公司代號'].apply(lambda x: math.isnan(x))]
            df['公司名稱'] = df.index
            df['公司代號'] = df['公司代號'].astype(int).astype(str)
            df = df.set_index('公司代號')
            df_final = pd.concat([df_final, df], axis=0, sort=False)
        except Exception as e:
            continue

    return df_final

# %%
storage = "financial_statement/"

if not os.path.exists(storage+'duration_coverage_FS.csv'):
    pd.DataFrame({'Season':[], 'Created_at':[]}).to_csv(storage+'duration_coverage_FS.csv', index=False)
existed_season = pd.read_csv(storage+'duration_coverage_FS.csv')['Season'].tolist()

df_PL = pd.read_csv('P&L.csv') if os.path.exists('P&L.csv') else pd.DataFrame()
df_BS = pd.read_csv('Balance_Sheet.csv') if os.path.exists('Balance_Sheet.csv') else pd.DataFrame()
df_FA = pd.read_csv('Financial_Analysis.csv') if os.path.exists('Financial_Analysis.csv') else pd.DataFrame()

# %%
year = 2013 - 1911
season = 3
url = 'https://mops.twse.com.tw/mops/web/ajax_t163sb04'
df_final = pd.DataFrame()
r = requests.post(url, {
    'encodeURIComponent':1,
    'step':1,
    'firstin':1,
    'off':1,
    'isQuery': 'Y',
    'TYPEK':"otc", # sii上市，otc上櫃，rotc興櫃，pub公開發行
    'year':str(year),
    'season':str(season),

})
r.encoding = 'utf8'
r.text

# %%
#dfs = pd.read_html(r.text, header=None)
#df = pd.concat(dfs[1:], axis=0, sort=False)
#df['年份'] = pd.Series([year] * df.shape[0])
#df['季度'] = pd.Series([season] * df.shape[0])
#df = df.set_index(['公司名稱']).apply(lambda s: pd.to_numeric(s, errors='ceorce'))
df['公司名稱'] = df.index
df['公司代號'] = df['公司代號'].astype(str)
df = df.set_index('公司代號')
df
# Out:
#              收益      支出及費用      營業利益     營業外損益   稅前淨利（淨損）  所得稅利益（費用）  \
# 公司代號
# 6015   786345.0   726791.0   59554.0  142376.0   201930.0     5447.0
# 6016  1437683.0  1576334.0 -138651.0   86777.0   -51874.0   -17381.0
# 6020   349513.0   124016.0  225497.0   21221.0   246718.0    18707.0
# 6021   525912.0   376332.0  149580.0   56071.0   205651.0    -5357.0
# 6023  1876831.0  1693253.0  183578.0  369604.0   553182.0   -98233.0
# 1258        NaN        NaN       NaN       NaN    47350.0        NaN
# 1259        NaN        NaN       NaN       NaN    43198.0        NaN
# 1333        NaN        NaN       NaN       NaN    14755.0        NaN
# 1336        NaN        NaN       NaN       NaN   -22348.0        NaN
# 1565        NaN        NaN       NaN       NaN  1344054.0        NaN
# 1569        NaN        NaN       NaN       NaN   -65272.0        NaN
# 1570        NaN        NaN       NaN       NaN    78229.0        NaN
# 1580        NaN        NaN       NaN       NaN   435153.0        NaN
# 1584        NaN        NaN       NaN       NaN  -135362.0        NaN
# 1586        NaN        NaN       NaN       NaN    28043.0        NaN
# 1591        NaN        NaN       NaN       NaN    48073.0        NaN
# 1593        NaN        NaN       NaN       NaN    31787.0        NaN
# 1595        NaN        NaN       NaN       NaN   289446.0        NaN
# 1597        NaN        NaN       NaN       NaN    78588.0        NaN
# 1599        NaN        NaN       NaN       NaN    99592.0        NaN
# 1742        NaN        NaN       NaN       NaN    -9978.0        NaN
# 1752        NaN        NaN       NaN       NaN     2582.0        NaN
# 1777        NaN        NaN       NaN       NaN    72186.0        NaN
# 1781        NaN        NaN       NaN       NaN    43567.0        NaN
# 1784        NaN        NaN       NaN       NaN    27127.0        NaN
# 1785        NaN        NaN       NaN       NaN   -12962.0        NaN
# 1787        NaN        NaN       NaN       NaN    86732.0        NaN
# 1788        NaN        NaN       NaN       NaN   205423.0        NaN
# 1795        NaN        NaN       NaN       NaN    26296.0        NaN
# 1799        NaN        NaN       NaN       NaN   -56860.0        NaN
# ...         ...        ...       ...       ...        ...        ...
# 8905        NaN        NaN       NaN       NaN   431410.0        NaN
# 8906        NaN        NaN       NaN       NaN   -16658.0        NaN
# 8908        NaN        NaN       NaN       NaN   210836.0        NaN
# 8913        NaN        NaN       NaN       NaN    13937.0        NaN
# 8916        NaN        NaN       NaN       NaN   406028.0        NaN
# 8917        NaN        NaN       NaN       NaN   136166.0        NaN
# 8921        NaN        NaN       NaN       NaN    62146.0        NaN
# 8923        NaN        NaN       NaN       NaN    10927.0        NaN
# 8924        NaN        NaN       NaN       NaN  -174946.0        NaN
# 8927        NaN        NaN       NaN       NaN    10248.0        NaN
# 8928        NaN        NaN       NaN       NaN   -38781.0        NaN
# 8929        NaN        NaN       NaN       NaN    86499.0        NaN
# 8930        NaN        NaN       NaN       NaN   205913.0        NaN
# 8931        NaN        NaN       NaN       NaN   105374.0        NaN
# 8932        NaN        NaN       NaN       NaN    42591.0        NaN
# 8933        NaN        NaN       NaN       NaN   159354.0        NaN
# 8934        NaN        NaN       NaN       NaN    39662.0        NaN
# 8935        NaN        NaN       NaN       NaN   -70936.0        NaN
# 8936        NaN        NaN       NaN       NaN   321244.0        NaN
# 8937        NaN        NaN       NaN       NaN    22008.0        NaN
# 8938        NaN        NaN       NaN       NaN  -186934.0        NaN
# 8941        NaN        NaN       NaN       NaN   -33758.0        NaN
# 8942        NaN        NaN       NaN       NaN   566166.0        NaN
# 9949        NaN        NaN       NaN       NaN     1591.0        NaN
# 9950        NaN        NaN       NaN       NaN    66096.0        NaN
# 9951        NaN        NaN       NaN       NaN   458540.0        NaN
# 9960        NaN        NaN       NaN       NaN    36196.0        NaN
# 9962        NaN        NaN       NaN       NaN    73302.0        NaN
# 5820        NaN        NaN       NaN       NaN        NaN        NaN
# 4707        NaN        NaN       NaN       NaN        NaN        NaN
#
#       繼續營業單位本期淨利（淨損）  停業單位損益  合併前非屬共同控制股權損益   本期淨利（淨損）  ...  繼續營業單位稅前損益  \
# 公司代號                                                    ...
# 6015          207377     NaN            NaN   207377.0  ...         NaN
# 6016          -69255     NaN            NaN   -69255.0  ...         NaN
# 6020          265425     0.0            NaN   265425.0  ...         NaN
# 6021          200294     NaN            NaN   200294.0  ...         NaN
# 6023          454949     NaN            NaN   454949.0  ...         NaN
# 1258           36642     NaN            NaN    36642.0  ...         NaN
# 1259           25616     NaN            NaN    25616.0  ...         NaN
# 1333           10727     0.0            NaN    10727.0  ...         NaN
# 1336          -19066     NaN            NaN   -19066.0  ...         NaN
# 1565         1158217     NaN            NaN  1158217.0  ...         NaN
# 1569          -48365     NaN            NaN   -48365.0  ...         NaN
# 1570           58931     NaN            NaN    58931.0  ...         NaN
# 1580          346076     NaN            NaN   346076.0  ...         NaN
# 1584         -135495     NaN            NaN  -135495.0  ...         NaN
# 1586           16803     NaN            NaN    16803.0  ...         NaN
# 1591           34974     NaN            NaN    34974.0  ...         NaN
# 1593           25945     NaN            NaN    25945.0  ...         NaN
# 1595          223909     NaN            NaN   223909.0  ...         NaN
# 1597           60003     NaN            NaN    60003.0  ...         NaN
# 1599           82258     NaN            NaN    82258.0  ...         NaN
# 1742          -11518     NaN            NaN   -11518.0  ...         NaN
# 1752           -3709     NaN            NaN    -3709.0  ...         NaN
# 1777           58118     NaN            NaN    58118.0  ...         NaN
# 1781           32326     NaN            NaN    32326.0  ...         NaN
# 1784           19457     NaN            NaN    19457.0  ...         NaN
# 1785         -153967     NaN            NaN  -153967.0  ...         NaN
# 1787           69448     NaN            NaN    69448.0  ...         NaN
# 1788          165488     NaN            NaN   165488.0  ...         NaN
# 1795           26986     NaN            NaN    26986.0  ...         NaN
# 1799          -57097     NaN            NaN   -57097.0  ...         NaN
# ...              ...     ...            ...        ...  ...         ...
# 8905          404764     NaN            NaN   404764.0  ...         NaN
# 8906          -16658     NaN            NaN   -16658.0  ...         NaN
# 8908          175029     NaN            NaN   175029.0  ...         NaN
# 8913           11089  5878.0            NaN    16967.0  ...         NaN
# 8916          315576     0.0            NaN   315576.0  ...         NaN
# 8917          112754     NaN            NaN   112754.0  ...         NaN
# 8921           51394     NaN            NaN    51394.0  ...         NaN
# 8923            9127     0.0            NaN     9127.0  ...         NaN
# 8924         -144758     NaN            NaN  -144758.0  ...         NaN
# 8927            5428     NaN            NaN     5428.0  ...         NaN
# 8928          -63447     NaN            NaN   -63447.0  ...         NaN
# 8929           60313     NaN            NaN    60313.0  ...         NaN
# 8930          205554     NaN            NaN   205554.0  ...         NaN
# 8931           86208     NaN            NaN    86208.0  ...         NaN
# 8932           50090     NaN            NaN    50090.0  ...         NaN
# 8933          116474     NaN            NaN   116474.0  ...         NaN
# 8934           14110     NaN            NaN    14110.0  ...         NaN
# 8935          -75296     NaN            NaN   -75296.0  ...         NaN
# 8936          269601     NaN            NaN   269601.0  ...         NaN
# 8937           18815     NaN            NaN    18815.0  ...         NaN
# 8938         -188364     NaN            NaN  -188364.0  ...         NaN
# 8941          -33754     0.0            NaN   -33754.0  ...         NaN
# 8942          436709     NaN            NaN   436709.0  ...         NaN
# 9949           -4028     NaN            NaN    -4028.0  ...         NaN
# 9950           48838     NaN            NaN    48838.0  ...         NaN
# 9951          368721     NaN            NaN   368721.0  ...         NaN
# 9960           28208     NaN            NaN    28208.0  ...         NaN
# 9962           60248     NaN            NaN    60248.0  ...         NaN
# 5820         1367490     NaN            NaN        NaN  ...   1386916.0
# 4707         2435326     NaN            NaN  2435326.0  ...         NaN
#
#       所得稅（費用）利益  本期稅後淨利（淨損）          收入         支出  繼續營業單位稅前淨利（淨損）    其他綜合損益  \
# 公司代號
# 6015        NaN         NaN         NaN        NaN             NaN       NaN
# 6016        NaN         NaN         NaN        NaN             NaN       NaN
# 6020        NaN         NaN         NaN        NaN             NaN       NaN
# 6021        NaN         NaN         NaN        NaN             NaN       NaN
# 6023        NaN         NaN         NaN        NaN             NaN       NaN
# 1258        NaN         NaN         NaN        NaN             NaN       NaN
# 1259        NaN         NaN         NaN        NaN             NaN       NaN
# 1333        NaN         NaN         NaN        NaN             NaN       NaN
# 1336        NaN         NaN         NaN        NaN             NaN       NaN
# 1565        NaN         NaN         NaN        NaN             NaN       NaN
# 1569        NaN         NaN         NaN        NaN             NaN       NaN
# 1570        NaN         NaN         NaN        NaN             NaN       NaN
# 1580        NaN         NaN         NaN        NaN             NaN       NaN
# 1584        NaN         NaN         NaN        NaN             NaN       NaN
# 1586        NaN         NaN         NaN        NaN             NaN       NaN
# 1591        NaN         NaN         NaN        NaN             NaN       NaN
# 1593        NaN         NaN         NaN        NaN             NaN       NaN
# 1595        NaN         NaN         NaN        NaN             NaN       NaN
# 1597        NaN         NaN         NaN        NaN             NaN       NaN
# 1599        NaN         NaN         NaN        NaN             NaN       NaN
# 1742        NaN         NaN         NaN        NaN             NaN       NaN
# 1752        NaN         NaN         NaN        NaN             NaN       NaN
# 1777        NaN         NaN         NaN        NaN             NaN       NaN
# 1781        NaN         NaN         NaN        NaN             NaN       NaN
# 1784        NaN         NaN         NaN        NaN             NaN       NaN
# 1785        NaN         NaN         NaN        NaN             NaN       NaN
# 1787        NaN         NaN         NaN        NaN             NaN       NaN
# 1788        NaN         NaN         NaN        NaN             NaN       NaN
# 1795        NaN         NaN         NaN        NaN             NaN       NaN
# 1799        NaN         NaN         NaN        NaN             NaN       NaN
# ...         ...         ...         ...        ...             ...       ...
# 8905        NaN         NaN         NaN        NaN             NaN       NaN
# 8906        NaN         NaN         NaN        NaN             NaN       NaN
# 8908        NaN         NaN         NaN        NaN             NaN       NaN
# 8913        NaN         NaN         NaN        NaN             NaN       NaN
# 8916        NaN         NaN         NaN        NaN             NaN       NaN
# 8917        NaN         NaN         NaN        NaN             NaN       NaN
# 8921        NaN         NaN         NaN        NaN             NaN       NaN
# 8923        NaN         NaN         NaN        NaN             NaN       NaN
# 8924        NaN         NaN         NaN        NaN             NaN       NaN
# 8927        NaN         NaN         NaN        NaN             NaN       NaN
# 8928        NaN         NaN         NaN        NaN             NaN       NaN
# 8929        NaN         NaN         NaN        NaN             NaN       NaN
# 8930        NaN         NaN         NaN        NaN             NaN       NaN
# 8931        NaN         NaN         NaN        NaN             NaN       NaN
# 8932        NaN         NaN         NaN        NaN             NaN       NaN
# 8933        NaN         NaN         NaN        NaN             NaN       NaN
# 8934        NaN         NaN         NaN        NaN             NaN       NaN
# 8935        NaN         NaN         NaN        NaN             NaN       NaN
# 8936        NaN         NaN         NaN        NaN             NaN       NaN
# 8937        NaN         NaN         NaN        NaN             NaN       NaN
# 8938        NaN         NaN         NaN        NaN             NaN       NaN
# 8941        NaN         NaN         NaN        NaN             NaN       NaN
# 8942        NaN         NaN         NaN        NaN             NaN       NaN
# 9949        NaN         NaN         NaN        NaN             NaN       NaN
# 9950        NaN         NaN         NaN        NaN             NaN       NaN
# 9951        NaN         NaN         NaN        NaN             NaN       NaN
# 9960        NaN         NaN         NaN        NaN             NaN       NaN
# 9962        NaN         NaN         NaN        NaN             NaN       NaN
# 5820   -19426.0   1367490.0         NaN        NaN             NaN       NaN
# 4707        NaN         NaN  11628466.0  8818879.0       2809587.0  158369.0
#
#        年份  季度   公司名稱
# 公司代號
# 6015  102   3   宏遠證券
# 6016  102   3   康和證券
# 6020  102   3    大展證
# 6021  102   3    大慶證
# 6023  102   3   元大期貨
# 1258  102   3  其祥-KY
# 1259  102   3     安心
# 1333  102   3    恩得利
# 1336  102   3     台翰
# 1565  102   3   精華光學
# 1569  102   3     濱川
# 1570  102   3   力肯實業
# 1580  102   3   新麥企業
# 1584  102   3   精剛精密
# 1586  102   3   和勤精機
# 1591  102   3  駿吉-KY
# 1593  102   3     祺驊
# 1595  102   3   川寶科技
# 1597  102   3     直得
# 1599  102   3    宏佳騰
# 1742  102   3     台蠟
# 1752  102   3     南光
# 1777  102   3     生泰
# 1781  102   3   合世生醫
# 1784  102   3   訊聯生技
# 1785  102   3    光洋科
# 1787  102   3    福盈科
# 1788  102   3   杏昌生技
# 1795  102   3   美時製藥
# 1799  102   3     易威
# ...   ...  ..    ...
# 8905  102   3   裕國冷凍
# 8906  102   3   花王企業
# 8908  102   3     欣雄
# 8913  102   3     全銓
# 8916  102   3     光隆
# 8917  102   3     欣泰
# 8921  102   3   沈氏藝印
# 8923  102   3   時報文化
# 8924  102   3   大田精密
# 8927  102   3     北基
# 8928  102   3     鉅明
# 8929  102   3     富堡
# 8930  102   3     青鋼
# 8931  102   3   大園汽電
# 8932  102   3   宏大拉鍊
# 8933  102   3    愛地雅
# 8934  102   3     衡平
# 8935  102   3     邦泰
# 8936  102   3   國統國際
# 8937  102   3   合騏工業
# 8938  102   3     明安
# 8941  102   3     關中
# 8942  102   3     森鉅
# 9949  102   3     琉園
# 9950  102   3   萬國通路
# 9951  102   3   皇田工業
# 9960  102   3    邁達康
# 9962  102   3   有益鋼鐵
# 5820  102   3   日盛金控
# 4707  102   3     磐亞
#
# [617 rows x 49 columns]

# %%
financial_statement(2014, 3, type='PL')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/tenacity/__init__.py in call(self, fn, *args, **kwargs)
#     360                 try:
# --> 361                     result = fn(*args, **kwargs)
#     362                 except BaseException:
#
# <ipython-input-77-39add40c3a7d> in financial_statement(year, season, type)
#      32         df['季度'] = pd.Series([season] * df.shape[0])
# ---> 33         df = pd.set_index(['公司名稱']).apply(lambda s: pd.to_numeric(s, errors='ceorce'))
#      34         df['年份'] = pd.Series([year] * df.shape[0])
#
# AttributeError: module 'pandas' has no attribute 'set_index'
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-78-3ee5d15ab1cf> in <module>
# ----> 1 financial_statement(2014, 3, type='PL')
#
# //anaconda3/lib/python3.7/site-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     290         @_utils.wraps(f)
#     291         def wrapped_f(*args, **kw):
# --> 292             return self.call(f, *args, **kw)
#     293
#     294         def retry_with(*args, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/tenacity/__init__.py in call(self, fn, *args, **kwargs)
#     356             retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     357         while True:
# --> 358             do = self.iter(retry_state=retry_state)
#     359             if isinstance(do, DoAttempt):
#     360                 try:
#
# //anaconda3/lib/python3.7/site-packages/tenacity/__init__.py in iter(self, retry_state)
#     330             if self.reraise:
#     331                 raise retry_exc.reraise()
# --> 332             six.raise_from(retry_exc, fut.exception())
#     333
#     334         if self.wait:
#
# //anaconda3/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# RetryError: RetryError[<Future at 0x11f24df28 state=finished raised AttributeError>]

# %%
# Main Part - Start from 2013-1
for year in list(range(2013, datetime.now().year+1)):
    for season in list(range(1, 5)):
        handling_season = "{0}-{1}".format(str(year), str(season))
        
        record_str = handling_season+" - 綜合損益彙總表"

        if record_str in existed_season:
            print("Pass: ", record_str)
        else:
            print("Handling: ", record_str)
            try:
	            df_PL = pd.concat([df_PL, financial_statement(year, season, type='PL')], axis=0, sort=False)
	            duration_covered = duration_covered.append(pd.DataFrame({'Season':[record_str], 'Created_at':[datetime.now()]}), sort=True)
	            duration_covered.to_csv(storage+'duration_coverage_FS.csv', index=False)
            except Exception as e:
            	print("Failed")
        
        record_str = handling_season+" - 資產負債彙總表"

        if record_str in existed_season:
            print("Pass: ", record_str)
        else:
            print("Handling: ", record_str)
            try:
                df_BS = pd.concat([df_BS, financial_statement(year, season, type='BS')], axis=0, sort=False)
                duration_covered = duration_covered.append(pd.DataFrame({'Season':[record_str], 'Created_at':[datetime.now()]}), sort=True)
                duration_covered.to_csv(storage+'duration_coverage_FS.csv', index=False)
            except Exception as e:
                print("Failed")
                
        
        record_str = handling_season+" - 營益分析彙總表"

        if record_str in existed_season:
            print("Pass: ", record_str)
        else:
            print("Handling: ", record_str)
            try:
                df_FA = pd.concat([df_FA, financial_analysis(year, season)], axis=0, sort=False)
                duration_covered = duration_covered.append(pd.DataFrame({'Season':[record_str], 'Created_at':[datetime.now()]}), sort=True)
                duration_covered.to_csv(storage+'duration_coverage_FS.csv', index=False)
            except Exception as e:
                print("Failed")
# Out:
# Pass:  2013-1 - 綜合損益彙總表
# Pass:  2013-1 - 資產負債彙總表
# Pass:  2013-1 - 營益分析彙總表
# Pass:  2013-2 - 綜合損益彙總表
# Pass:  2013-2 - 資產負債彙總表
# Pass:  2013-2 - 營益分析彙總表
# Handling:  2013-3 - 綜合損益彙總表
# Failed
# Handling:  2013-3 - 資產負債彙總表
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-8000a90cc3ff> in <module>
#      24             print("Handling: ", record_str)
#      25             try:
# ---> 26                 df_BS = pd.concat([df_BS, financial_statement(year, season, type='BS')], axis=0, sort=False)
#      27                 duration_covered = duration_covered.append(pd.DataFrame({'Season':[record_str], 'Created_at':[datetime.now()]}), sort=True)
#      28                 duration_covered.to_csv(storage+'duration_coverage_FS.csv', index=False)
#
# //anaconda3/lib/python3.7/site-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     290         @_utils.wraps(f)
#     291         def wrapped_f(*args, **kw):
# --> 292             return self.call(f, *args, **kw)
#     293
#     294         def retry_with(*args, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/tenacity/__init__.py in call(self, fn, *args, **kwargs)
#     356             retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     357         while True:
# --> 358             do = self.iter(retry_state=retry_state)
#     359             if isinstance(do, DoAttempt):
#     360                 try:
#
# //anaconda3/lib/python3.7/site-packages/tenacity/__init__.py in iter(self, retry_state)
#     317             and isinstance(retry_state.outcome.exception(), TryAgain)
#     318         if not (is_explicit_retry or self.retry(retry_state=retry_state)):
# --> 319             return fut.result()
#     320
#     321         if self.after is not None:
#
# //anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# //anaconda3/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# //anaconda3/lib/python3.7/site-packages/tenacity/__init__.py in call(self, fn, *args, **kwargs)
#     359             if isinstance(do, DoAttempt):
#     360                 try:
# --> 361                     result = fn(*args, **kwargs)
#     362                 except BaseException:
#     363                     retry_state.set_exception(sys.exc_info())
#
# <ipython-input-40-010d833a2d8c> in financial_statement(year, season, type)
#      27         r.encoding = 'utf8'
#      28
# ---> 29         dfs = pd.read_html(r.text, header=None)
#      30         df = pd.concat(dfs[1:], axis=0, sort=False)\
#      31                  .set_index(['公司名稱'])\
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     917
#     918     ret = []
# --> 919     for table in tables:
#     920         try:
#     921             ret.append(_data_to_frame(data=table, **kwargs))
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in <genexpr>(.0)
#     220         """
#     221         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
# --> 222         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     223
#     224     def _attr_getter(self, obj, attr):
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse_thead_tbody_tfoot(self, table_html)
#     420
#     421         header = self._expand_colspan_rowspan(header_rows)
# --> 422         body = self._expand_colspan_rowspan(body_rows)
#     423         footer = self._expand_colspan_rowspan(footer_rows)
#     424
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _expand_colspan_rowspan(self, rows)
#     466
#     467                 # Append the text from this <td>, colspan times
# --> 468                 text = _remove_whitespace(self._text_getter(td))
#     469                 rowspan = int(self._attr_getter(td, 'rowspan') or 1)
#     470                 colspan = int(self._attr_getter(td, 'colspan') or 1)
#
# KeyboardInterrupt:

# %%
df_PL.to_csv(storage+'P&L.csv')
df_BS.to_csv(storage+'Balance_Sheet.csv')
df_FA.to_csv(storage+'Financial_Analysis.csv')
